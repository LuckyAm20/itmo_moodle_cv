# %%
import cv2

# %%
img = cv2.imread("image.png")
img.shape
# Out:
# (1080, 1920, 3)

# %%
height, width, channels = img.shape
print("width =", width)
print("height =", height)
# Out:
# width = 1920
# height = 1080

# %%
b, g, r = img[509, 980]
print("R =", int(r))
print("G =", int(g))
print("B =", int(b))
# Out:
# R = 255
# G = 176
# B = 153
